# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.0 버전부터 사용 transfer learning이란 기법을 사용

# %%
# !pip install tensorflow-hub

# %%
# !pip install tensorflow-datasets
# Out:
# ...
#   Stored in directory: C:\Users\USER\AppData\Local\pip\Cache\wheels\5b\d7\0f\e58eae695403de585269f4e4a94e0cd6ca60ec0c202936fa4a
# ...
#   Stored in directory: C:\Users\USER\AppData\Local\pip\Cache\wheels\92\84\9f\75e2235effae0e1c5a5c0626a503e532bbffcb7e79e672b606
# ...
#   Stored in directory: C:\Users\USER\AppData\Local\pip\Cache\wheels\9e\3d\a2\1bec8bb7db80ab3216dbc33092bb7ccd0debfb8ba42b5668d5
# Successfully built dill promise googleapis-common-protos
# ...

# %%
import tensorflow as tf

# %%
import numpy as np

# %%
import tensorflow_hub as hub

# %%
import tensorflow_datasets as tfds

# %% [markdown]
# as ~ds가 붙으면 도메인마다 다르다.

# %%
print("버전: ", tf.__version__)
print("즉시 실행 모드: ", tf.executing_eagerly())
print("허브 버전: ", hub.__version__)
print("GPU ", "사용 가능" if tf.test.is_gpu_available() else "사용 불가능")
# Out:
# 버전:  2.0.0-beta1
# 즉시 실행 모드:  True
# 허브 버전:  0.5.0
# GPU  사용 불가능

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.0부터 새로생겼음

# %%
dir(tfds) #비정형데이터와 가깝다.
# Out:
# ['GenerateMode',
#  'Split',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'absolute_import',
#  'as_numpy',
#  'audio',
#  'builder',
#  'core',
#  'disable_progress_bar',
#  'division',
#  'download',
#  'features',
#  'file_adapter',
#  'image',
#  'is_dataset_on_gcs',
#  'list_builders',
#  'load',
#  'percent',
#  'print_function',
#  'public_api',
#  'structured',
#  'testing',
#  'text',
#  'tf_compat',
#  'translate',
#  'units',
#  'version',
#  'video']

# %%
dir(tfds.Split)
# Out:
# ['ALL',
#  'TEST',
#  'TRAIN',
#  'VALIDATION',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
dir(tfds.Split.TRAIN)
# Out:
# ['__abstractmethods__',
#  '__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_name',
#  'get_read_instruction',
#  'subsplit']

# %%
# 훈련 세트를 6대 4로 나눕니다.
# 결국 훈련에 15,000개 샘플, 검증에 10,000개 샘플, 테스트에 25,000개 샘플을 사용하게 됩니다.
train_validation_split = tfds.Split.TRAIN.subsplit([6, 4])

(train_data, validation_data), test_data = tfds.load(
    name="imdb_reviews", 
    split=(train_validation_split, tfds.Split.TEST),
    as_supervised=True)
# Out:
# ...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-45-541bb0460665> in <module>
#       6     name="imdb_reviews",
#       7     split=(train_validation_split, tfds.Split.TEST),
# ----> 8     as_supervised=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_datasets\core\api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      50     _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51     _check_required(fn, kwargs)
# ---> 52     return fn(*args, **kwargs)
#      53
#      54   return disallow_positional_args_dec(wrapped)  # pylint: disable=no-value-for-parameter
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_datasets\core\registered.py in load(name, split, data_dir, batch_size, download, as_supervised, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
# ...

# %% [markdown]
# - 윈도우 버전에서는 애러가 날수있다.(beta version이기 때문에 윈도우는 정식버전이 나왔을떄 실행가능할 경우가 높다.)
# - 구글 코랩으로 실행

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
