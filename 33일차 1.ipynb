# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# TF.2.0 Beta

# %%
# !pip install -q tensorflow==2.0.0-beta1

# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.fashion_mnist.load_data()

# %%
(X_train, y_train),(X_test,y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 이미지 데이타 또는 0과 1사이 아닌데이터들은 0과 1사이로 바꾸는 과정 255.0로 나눈다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# activation을 쓰는 방식은 2가지 방식이 있다. 문자열 방식과 객체방식이 있다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. optimizer
# 2. loss
# 3. metrics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# test 할떄는 evaluate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 예측할떄는 predict

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# beta에서 추가된 기법

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
X_test[0].shape
# Out:
# (28, 28)

# %%
X_test[0][np.newaxis].shape
# Out:
# (1, 28, 28)

# %%
np.expand_dims(X_test[0],0).shape
# Out:
# (1, 28, 28)

# %% [markdown]
# 바꾸는 이유는 모양을 맞춰야한다.
