# %%
import seaborn as sns #연습용데이타

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
x = tips.total_bill.plot

# %%
x.bar()

# %%
tips.groupby('sex').mean()[['tip']].plot.bar()

# %%
dust = pd.read_csv('a.csv',engine='python',encoding='cp949')

# %%
dust
# Out:
#              날짜   미세먼지농도 (㎍/㎥)  결과
# 0    2017-01-10             19  좋음
# 1    2017-01-11             20  좋음
# 2    2017-01-13             29  좋음
# 3    2017-01-14             40  보통
# 4    2017-01-20             20  좋음
# 5    2017-01-21             20  좋음
# 6    2017-01-27             25  좋음
# 7    2017-01-28             40  보통
# 8    2017-01-31             40  보통
# 9    2017-02-01             50  보통
# 10   2017-02-02             10  좋음
# 11   2017-02-03             22  좋음
# 12   2017-02-06             25  좋음
# 13   2017-02-07             27  좋음
# 14   2017-02-08             30  좋음
# 15   2017-02-09             41  보통
# 16   2017-02-10             42  보통
# 17   2017-02-11             19  좋음
# 18   2017-02-14             18  좋음
# 19   2017-02-15             20  좋음
# 20   2017-02-16             22  좋음
# 21   2017-02-17             43  보통
# 22   2017-02-22             43  보통
# 23   2017-02-23             41  보통
# 24   2017-02-24             20  좋음
# 25   2017-02-25             30  좋음
# ...

# %%
dust.columns[1]
# Out:
# ' 미세먼지농도 (㎍/㎥)'

# %%
dust.set_index('날짜')[dust.columns[1]].plot.line()

# %%
t = dust.set_index('날짜')

# %%
t
# Out:
#              미세먼지농도 (㎍/㎥)  결과
# 날짜
# 2017-01-10             19  좋음
# 2017-01-11             20  좋음
# 2017-01-13             29  좋음
# 2017-01-14             40  보통
# 2017-01-20             20  좋음
# 2017-01-21             20  좋음
# 2017-01-27             25  좋음
# 2017-01-28             40  보통
# 2017-01-31             40  보통
# 2017-02-01             50  보통
# 2017-02-02             10  좋음
# 2017-02-03             22  좋음
# 2017-02-06             25  좋음
# 2017-02-07             27  좋음
# 2017-02-08             30  좋음
# 2017-02-09             41  보통
# 2017-02-10             42  보통
# 2017-02-11             19  좋음
# 2017-02-14             18  좋음
# 2017-02-15             20  좋음
# 2017-02-16             22  좋음
# 2017-02-17             43  보통
# 2017-02-22             43  보통
# 2017-02-23             41  보통
# 2017-02-24             20  좋음
# 2017-02-25             30  좋음
# 2017-02-26             35  보통
# 2017-02-27             37  보통
# 2017-03-01             38  보통
# 2017-03-02             39  보통
# ...

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 2017-01-10 to 2017-12-31
# Data columns (total 2 columns):
#  미세먼지농도 (㎍/㎥)    250 non-null int64
# 결과               250 non-null object
# dtypes: int64(1), object(1)
# memory usage: 5.9+ KB

# %%
dust['date'] = pd.to_datetime(dust['날짜'])

# %%
dust.set_index('date')[dust.columns[1]]['2017-01' : '2017-02']
# Out:
# date
# 2017-01-10    19
# 2017-01-11    20
# 2017-01-13    29
# 2017-01-14    40
# 2017-01-20    20
# 2017-01-21    20
# 2017-01-27    25
# 2017-01-28    40
# 2017-01-31    40
# 2017-02-01    50
# 2017-02-02    10
# 2017-02-03    22
# 2017-02-06    25
# 2017-02-07    27
# 2017-02-08    30
# 2017-02-09    41
# 2017-02-10    42
# 2017-02-11    19
# 2017-02-14    18
# 2017-02-15    20
# 2017-02-16    22
# 2017-02-17    43
# 2017-02-22    43
# 2017-02-23    41
# 2017-02-24    20
# 2017-02-25    30
# 2017-02-26    35
# 2017-02-27    37
# Name:  미세먼지농도 (㎍/㎥), dtype: int64

# %%
dust.set_index('date')[dust.columns[1]].resample('M').mean().plot.line()  #월간으로 묶음

# %%
dust.set_index('date')[dust.columns[1]].plot.line()  #일간으로 묶음

# %% [markdown]
# pandas(기초 통계분석(데이터 그 자체))  - 최종목표는 예측분석(pandas로는 할수 없다.)
#
# 1. 기초 통계분석(EDA = 탐색적 데이터 분석)
#   - 단순한 통계값 분석
#   - 그래프를 이용한 분석
# 2. 전처리
